# %% [markdown]
# Script to practice my data analysis and visualization skills in python to get them up to where I am with R.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pip
# %pip install plotnine
from plotnine import * 
#ahhhhhhh yeeeeeeaaaaaa ggplot in python!

#read in datasets as CSV files
df_adidas = pd.read_csv("C:/Users/Chance/Documents/DataScienceAnalytics/adidas_usa_1.csv")
df_nike = pd.read_csv("C:/Users/Chance/Documents/DataScienceAnalytics/nike_2020_04_13.csv")
#convert to dataframe
df_adidas = pd.DataFrame(df_adidas)
df_nike = pd.DataFrame(df_nike)

#TODO: COMBINE THE NIKE AND ADIDAS DATAFRAMES INTO A SINGLE DATAFRAME
# Out:
# Requirement already satisfied: plotnine in c:\users\chance\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (3.5.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (0.5.2)
# Requirement already satisfied: pandas>=1.3.5 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (1.4.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (1.9.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (0.13.2)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (1.21.5)
# Requirement already satisfied: mizani>=0.8.1 in c:\users\chance\anaconda3\lib\site-packages (from plotnine) (0.8.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\chance\anaconda3\lib\site-packages (from matplotlib>=3.5.0->plotnine) (0.11.0)
# Requirement already satisfied: palettable in c:\users\chance\anaconda3\lib\site-packages (from mizani>=0.8.1->plotnine) (3.3.0)
# Requirement already satisfied: tzdata in c:\users\chance\anaconda3\lib\site-packages (from mizani>=0.8.1->plotnine) (2022.7)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chance\anaconda3\lib\site-packages (from pandas>=1.3.5->plotnine) (2022.1)
# Requirement already satisfied: six in c:\users\chance\anaconda3\lib\site-packages (from patsy>=0.5.1->plotnine) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Try using matplotlib first before trying to make ggplot work in python.

# %%
#name = df['car'].head(12)
#price = df['price'].head(12)
#plt.bar(name[0:10], price[0:10])

ProductName = df_nike['Product Name'].head(20)
Price = df_nike['Sale Price'].head(20)
plt.bar(ProductName, Price)
plt.show()

# %% [markdown]
# That worked, though I'll need to rotate the labels on the x-axis. Now try using plotnine for ggplot syntax

# %%
ggplot(df_nike, aes(x='Product Name', y = 'Sale Price')) + \
    ylim(0,200)
# Out:
# <ggplot: (114691890517)>

# %% [markdown]
# Ok, well, it does work. However, there's so many products that the entire x-axis is essentially a blur. Also, it seems that all the prices are negative, which is not correct. Let's check the structure of the dataframe to see whats' going on.

# %%
df_nike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643 entries, 0 to 642
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   URL            643 non-null    object
#  1   Product Name   643 non-null    object
#  2   Product ID     643 non-null    object
#  3   Listing Price  643 non-null    int64
#  4   Sale Price     643 non-null    float64
#  5   Discount       643 non-null    int64
#  6   Brand          643 non-null    object
#  7   Description    640 non-null    object
#  8   Rating         643 non-null    float64
#  9   Reviews        643 non-null    int64
#  10  Images         572 non-null    object
#  11  Last Visited   643 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 60.4+ KB

# %% [markdown]
# It is showing as a float, so I'm unsure why it's showing up like that in the plot. How does the adidas dataframe look?

# %%
df_adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 845 entries, 0 to 844
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   url             845 non-null    object
#  1   name            845 non-null    object
#  2   sku             845 non-null    object
#  3   selling_price   845 non-null    float64
#  4   original_price  829 non-null    float64
#  5   currency        845 non-null    object
#  6   availability    845 non-null    object
#  7   color           845 non-null    object
#  8   category        845 non-null    object
#  9   source          845 non-null    object
#  10  source_website  845 non-null    object
#  11  breadcrumbs     845 non-null    object
#  12  description     845 non-null    object
#  13  brand           845 non-null    object
#  14  images          845 non-null    object
#  15  country         845 non-null    object
#  16  language        845 non-null    object
#  17  average_rating  845 non-null    float64
#  18  reviews_count   845 non-null    float64
#  19  crawled_at      845 non-null    object
# dtypes: float64(4), object(16)
# memory usage: 132.2+ KB

# %%
adidas_ProductName=df_adidas['name'].head(20)
adidas_Price=df_adidas['selling_price'].head(20)

plt.bar(adidas_ProductName, adidas_Price)
plt.show()

# %% [markdown]
# Ok, Adidas worked for the matplotlib method. Now try ggplot. I assume I'll have the same weird issue.

# %%
ggplot(df_adidas, aes(x='name', y = 'selling_price')) + \
    ylim(0,200)
# Out:
# <ggplot: (114690761765)>

# %% [markdown]
# Yup, same issue. I'll have to come back to this to see what's causing the issue in plotnine but not in matplotlib
